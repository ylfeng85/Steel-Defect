# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import keras
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import cv2
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
import tensorflow as tf
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from collections import Counter
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
from keras.layers import Embedding
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, LeakyReLU
from keras.layers import Flatten, Conv1D, SpatialDropout1D, MaxPooling1D,AveragePooling1D, merge, concatenate, Input, Dropout

from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import schedules

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# tf.config.set_visible_devices([], 'GPU')

# %%
files = []
directory = ''
for dirname, _, filenames in os.walk('/Users/tf/severstal-steel-defect-detection/train_images'):
    files = filenames
    directory = dirname

# %%
len(files)
# Out:
# 12568

# %%
file_df = pd.DataFrame(files, columns = ['ImageId'])

# %%
data = pd.read_csv("/Users/tf/severstal-steel-defect-detection/train.csv")

# %%
data.shape
# Out:
# (7095, 3)

# %%
data.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
data['ones'] = 1

# %%
pivot = data[['ImageId','ClassId','ones']].pivot(index='ImageId', columns='ClassId',values='ones').reset_index()

# %%
file_df = file_df.merge(pivot, how='left', on='ImageId').fillna(0)

# %%
file_df.shape
# Out:
# (12568, 5)

# %%
file_df.head()
# Out:
#          ImageId    1    2    3    4
# 0  58ee62fd7.jpg  0.0  0.0  1.0  0.0
# 1  eeffa4c49.jpg  1.0  0.0  1.0  0.0
# 2  0dced41aa.jpg  0.0  0.0  0.0  0.0
# 3  bd2366c49.jpg  0.0  0.0  0.0  0.0
# 4  e2bdd4236.jpg  0.0  0.0  1.0  0.0

# %%
# train/valid and test split

df_test = file_df.sample(frac=0.15, random_state=0)
print(df_test.shape)
# Out:
# (1885, 5)

# %%
exclude = file_df.index.isin(df_test.index)
df_train = file_df.loc[~exclude]
print(df_train.shape)
# Out:
# (10683, 5)

# %%
# remove non-defect rows

df_train = df_train[(df_train[[1,2,3,4]] != 0).any(axis=1)]
print(df_train.shape)
# Out:
# (5648, 5)

# %%
#  oversample data

df_train['rpt'] = 1 + df_train[1]*4 + df_train[4]*4 + df_train[2]*10 + \
                      df_train[1]*df_train[3]*4 + df_train[2]*df_train[3]*8 + df_train[1]*df_train[2]*4 + \
                      df_train[1]*df_train[2]*df_train[3]*12 + df_train[2]*df_train[4]*12

# %%
df_train = df_train.reindex(df_train.index.repeat(df_train.rpt)).reset_index(drop=True).drop(['rpt'],axis=1)
df_train.shape
# Out:
# (14166, 5)

# %%
# plot resampled distribution

y_counts_old = file_df[[1,2,3,4]].to_numpy()

counts = Counter(str(l) for l in y_counts_old)
plt.figure(figsize=(15, 5))
plt.bar(*zip(*counts.items()))
plt.show()

y_counts_new = df_train[[1,2,3,4]].to_numpy()

counts = Counter(str(l) for l in y_counts_new)
plt.figure(figsize=(15, 5))
plt.bar(*zip(*counts.items()))
plt.show()

# %%
datagen=ImageDataGenerator(rescale=1./255., shear_range=20.0,
                           rotation_range=10, width_shift_range=0.2, height_shift_range=0.2,
                           horizontal_flip=True, vertical_flip=True, validation_split=0.15)

test_datagen=ImageDataGenerator(rescale=1./255.)

train_generator=datagen.flow_from_dataframe(dataframe=df_train,
                directory='/Users/tf/severstal-steel-defect-detection/train_images', subset="training",
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))

valid_generator=datagen.flow_from_dataframe(dataframe=df_train,
                directory='/Users/tf/severstal-steel-defect-detection/train_images', subset="validation",
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))

test_generator=test_datagen.flow_from_dataframe(dataframe=df_test,
                directory='/Users/tf/severstal-steel-defect-detection/train_images',
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))
# Out:
# Found 12042 validated image filenames.
# Found 2124 validated image filenames.
# Found 1885 validated image filenames.

# %%
def model(output_dim=4, num_filters=8, filter_sizes=[(1,3),(3,3),(3,1)], dropout=0.2):

    model_input = Input(shape=(71,71,1))

    pooled_outputs = []
    for i in range(len(filter_sizes)):
        conv = Conv2D(num_filters, kernel_size=filter_sizes[i], padding='same', activation=LeakyReLU(alpha=0.05))(model_input)
        conv = MaxPooling2D(pool_size=(2,2))(conv)
        pooled_outputs.append(conv)
    merge = concatenate(pooled_outputs)
    
    x = Conv2D(16,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(merge)
    x = Conv2D(16,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    
    x = Conv2D(32,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = Conv2D(32,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Conv2D(24,(1,1),activation=LeakyReLU(alpha=0.05))(x)
    x = BatchNormalization()(x)
    
    flat = Flatten()(x)
    
    dense = Dropout(dropout)(flat)
    dense = Dense(50,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    dense = Dense(24,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    dense = Dense(24,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    predictions = Dense(4,activation="sigmoid")(dense)
    
    model = Model(inputs=model_input,outputs=predictions)

    lr_schedule = schedules.ExponentialDecay(
        initial_learning_rate=0.0001,
        decay_steps=564,
        decay_rate=0.6)
    opt = optimizers.Adam(learning_rate=lr_schedule)
    
    model.compile(loss = 'binary_crossentropy', optimizer=opt, metrics=["accuracy",'binary_accuracy'])
    print(model.summary())
    
    return model

model = model()
# Out:
# Model: "model_51"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_54 (InputLayer)          [(None, 71, 71, 1)]  0           []
#
#  conv2d_430 (Conv2D)            (None, 71, 71, 8)    32          ['input_54[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 71, 71, 8)    80          ['input_54[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 71, 71, 8)    32          ['input_54[0][0]']
#
#  max_pooling2d_243 (MaxPooling2  (None, 35, 35, 8)   0           ['conv2d_430[0][0]']
#  D)
#
#  max_pooling2d_244 (MaxPooling2  (None, 35, 35, 8)   0           ['conv2d_431[0][0]']
#  D)
#
#  max_pooling2d_245 (MaxPooling2  (None, 35, 35, 8)   0           ['conv2d_432[0][0]']
#  D)
#
#  concatenate_53 (Concatenate)   (None, 35, 35, 24)   0           ['max_pooling2d_243[0][0]',
#                                                                   'max_pooling2d_244[0][0]',
#                                                                   'max_pooling2d_245[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 35, 35, 16)   3472        ['concatenate_53[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 35, 35, 16)   2320        ['conv2d_433[0][0]']
#
#  batch_normalization_161 (Batch  (None, 35, 35, 16)  64          ['conv2d_434[0][0]']
#  Normalization)
#
#  max_pooling2d_246 (MaxPooling2  (None, 17, 17, 16)  0           ['batch_normalization_161[0][0]']
#  D)
#
#  conv2d_435 (Conv2D)            (None, 17, 17, 32)   4640        ['max_pooling2d_246[0][0]']
#
#  conv2d_436 (Conv2D)            (None, 17, 17, 32)   9248        ['conv2d_435[0][0]']
#
#  batch_normalization_162 (Batch  (None, 17, 17, 32)  128         ['conv2d_436[0][0]']
#  Normalization)
#
#  max_pooling2d_247 (MaxPooling2  (None, 8, 8, 32)    0           ['batch_normalization_162[0][0]']
#  D)
#
#  conv2d_437 (Conv2D)            (None, 8, 8, 24)     792         ['max_pooling2d_247[0][0]']
#
#  batch_normalization_163 (Batch  (None, 8, 8, 24)    96          ['conv2d_437[0][0]']
#  Normalization)
#
#  flatten_51 (Flatten)           (None, 1536)         0           ['batch_normalization_163[0][0]']
#
#  dropout_169 (Dropout)          (None, 1536)         0           ['flatten_51[0][0]']
#
#  dense_169 (Dense)              (None, 50)           76850       ['dropout_169[0][0]']
#
#  dropout_170 (Dropout)          (None, 50)           0           ['dense_169[0][0]']
#
#  dense_170 (Dense)              (None, 24)           1224        ['dropout_170[0][0]']
#
#  dropout_171 (Dropout)          (None, 24)           0           ['dense_170[0][0]']
#
#  dense_171 (Dense)              (None, 24)           600         ['dropout_171[0][0]']
#
#  dropout_172 (Dropout)          (None, 24)           0           ['dense_171[0][0]']
#
#  dense_172 (Dense)              (None, 4)            100         ['dropout_172[0][0]']
#
# ==================================================================================================
# Total params: 99,678
# Trainable params: 99,534
# Non-trainable params: 144
# __________________________________________________________________________________________________
# None

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
print(STEP_SIZE_TRAIN)
print(STEP_SIZE_VALID)
print(STEP_SIZE_TEST)
# Out:
# 188
# 33
# 29

# %%
callback_list = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='./[model2]-{epoch:02d}-{val_loss:.3f}.h5'),
]

history = model.fit(x=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25,
                    callbacks=callback_list,
                    verbose=1)
# Out:
# Epoch 1/25
# 188/188 [==============================] - 95s 473ms/step - loss: 0.6736 - accuracy: 0.3189 - binary_accuracy: 0.5853 - val_loss: 0.6943 - val_accuracy: 0.1454 - val_binary_accuracy: 0.4782
# Epoch 2/25
# 188/188 [==============================] - 102s 542ms/step - loss: 0.5925 - accuracy: 0.3649 - binary_accuracy: 0.6763 - val_loss: 0.6509 - val_accuracy: 0.3674 - val_binary_accuracy: 0.5868
# Epoch 3/25
# 188/188 [==============================] - 113s 598ms/step - loss: 0.5651 - accuracy: 0.3825 - binary_accuracy: 0.6928 - val_loss: 0.5691 - val_accuracy: 0.4560 - val_binary_accuracy: 0.7156
# Epoch 4/25
# 188/188 [==============================] - 115s 607ms/step - loss: 0.5499 - accuracy: 0.4051 - binary_accuracy: 0.7004 - val_loss: 0.5139 - val_accuracy: 0.4569 - val_binary_accuracy: 0.7307
# Epoch 5/25
# 188/188 [==============================] - 116s 610ms/step - loss: 0.5380 - accuracy: 0.4133 - binary_accuracy: 0.7050 - val_loss: 0.5001 - val_accuracy: 0.4986 - val_binary_accuracy: 0.7322
# Epoch 6/25
# 188/188 [==============================] - 99s 516ms/step - loss: 0.5309 - accuracy: 0.4243 - binary_accuracy: 0.7099 - val_loss: 0.4892 - val_accuracy: 0.5133 - val_binary_accuracy: 0.7345
# Epoch 7/25
# 188/188 [==============================] - 94s 499ms/step - loss: 0.5259 - accuracy: 0.4259 - binary_accuracy: 0.7109 - val_loss: 0.4813 - val_accuracy: 0.4976 - val_binary_accuracy: 0.7393
# Epoch 8/25
# 188/188 [==============================] - 111s 592ms/step - loss: 0.5205 - accuracy: 0.4408 - binary_accuracy: 0.7166 - val_loss: 0.4804 - val_accuracy: 0.5227 - val_binary_accuracy: 0.7470
# Epoch 9/25
# 188/188 [==============================] - 118s 626ms/step - loss: 0.5153 - accuracy: 0.4410 - binary_accuracy: 0.7183 - val_loss: 0.4776 - val_accuracy: 0.5256 - val_binary_accuracy: 0.7464
# Epoch 10/25
# 188/188 [==============================] - 121s 639ms/step - loss: 0.5130 - accuracy: 0.4469 - binary_accuracy: 0.7182 - val_loss: 0.4733 - val_accuracy: 0.5256 - val_binary_accuracy: 0.7461
# Epoch 11/25
# 188/188 [==============================] - 114s 606ms/step - loss: 0.5093 - accuracy: 0.4559 - binary_accuracy: 0.7226 - val_loss: 0.4744 - val_accuracy: 0.5436 - val_binary_accuracy: 0.7505
# Epoch 12/25
# 188/188 [==============================] - 132s 704ms/step - loss: 0.5078 - accuracy: 0.4534 - binary_accuracy: 0.7225 - val_loss: 0.4731 - val_accuracy: 0.5350 - val_binary_accuracy: 0.7468
# Epoch 13/25
# 188/188 [==============================] - 137s 729ms/step - loss: 0.5043 - accuracy: 0.4527 - binary_accuracy: 0.7264 - val_loss: 0.4715 - val_accuracy: 0.5275 - val_binary_accuracy: 0.7483
# Epoch 14/25
# 188/188 [==============================] - 83s 439ms/step - loss: 0.5027 - accuracy: 0.4653 - binary_accuracy: 0.7264 - val_loss: 0.4682 - val_accuracy: 0.5341 - val_binary_accuracy: 0.7514
# Epoch 15/25
# 188/188 [==============================] - 59s 311ms/step - loss: 0.5038 - accuracy: 0.4650 - binary_accuracy: 0.7254 - val_loss: 0.4675 - val_accuracy: 0.5237 - val_binary_accuracy: 0.7513
# Epoch 16/25
# 188/188 [==============================] - 56s 298ms/step - loss: 0.5005 - accuracy: 0.4633 - binary_accuracy: 0.7274 - val_loss: 0.4658 - val_accuracy: 0.5341 - val_binary_accuracy: 0.7559
# Epoch 17/25
# 188/188 [==============================] - 62s 324ms/step - loss: 0.4994 - accuracy: 0.4708 - binary_accuracy: 0.7315 - val_loss: 0.4643 - val_accuracy: 0.5270 - val_binary_accuracy: 0.7546
# Epoch 18/25
# 188/188 [==============================] - 58s 306ms/step - loss: 0.5023 - accuracy: 0.4608 - binary_accuracy: 0.7271 - val_loss: 0.4663 - val_accuracy: 0.5421 - val_binary_accuracy: 0.7556
# Epoch 19/25
# 188/188 [==============================] - 66s 350ms/step - loss: 0.4997 - accuracy: 0.4719 - binary_accuracy: 0.7288 - val_loss: 0.4621 - val_accuracy: 0.5402 - val_binary_accuracy: 0.7552
# Epoch 20/25
# 188/188 [==============================] - 64s 340ms/step - loss: 0.4987 - accuracy: 0.4615 - binary_accuracy: 0.7286 - val_loss: 0.4631 - val_accuracy: 0.5516 - val_binary_accuracy: 0.7541
# Epoch 21/25
# 188/188 [==============================] - 63s 332ms/step - loss: 0.4967 - accuracy: 0.4680 - binary_accuracy: 0.7291 - val_loss: 0.4636 - val_accuracy: 0.5431 - val_binary_accuracy: 0.7586

# %% [markdown]
# ### Results

# %%
history_df = pd.DataFrame(history.history)
history_df.index += 1

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['loss','val_loss']], lw=2)
plt.title('Loss (Binary Cross Entropy)', fontsize=20)
plt.legend(['Training Loss','Validation Loss'], fontsize=12, loc=1)
plt.xlim(0.5,21.5)
plt.ylim(0.45,0.7)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.45, 0.75, step=0.05))
plt.grid()
plt.show()

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['accuracy','val_accuracy']], lw=2)
plt.title('Accuracy', fontsize=20)
plt.legend(['Training Accuracy','Validation Accuracy'], fontsize=12, loc=4)
plt.xlim(0.5,21.5)
plt.ylim(0.3,0.56)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.3, 0.6, step=0.05))
plt.grid()
plt.show()

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['binary_accuracy','val_binary_accuracy']], lw=2)
plt.title('Binary Accuracy', fontsize=20)
plt.legend(['Training Binary Accuracy','Validation Binary Accuracy'], fontsize=12, loc=4)
plt.xlim(0.5,21.5)
plt.ylim(0.575,0.775)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.575, 0.775, step=0.025))
plt.grid()
plt.show()

# %%
from keras.models import load_model
saved_model = load_model('/Users/tf/Desktop/[model3]-11-0.472.h5')

# %%
y_eval = saved_model.evaluate(valid_generator)
valid_generator.reset()

y_pred = saved_model.predict(valid_generator, verbose=1)
y_pred[y_pred > 0.5] = 1
y_pred[y_pred <= 0.5] = 0
y_pred = pd.DataFrame(y_pred)

y_test = df_train.loc[valid_generator.index_array]
# Out:
# 34/34 [==============================] - 10s 245ms/step - loss: 0.4631 - accuracy: 0.5414 - binary_accuracy: 0.7584
# 34/34 [==============================] - 9s 250ms/step

# %%
print(y_eval)
# Out:
# [0.46312275528907776, 0.5414312481880188, 0.7583568692207336]

# %%
tns, fps, fns, tps = [],[],[],[]

for i in range(4):
    tn, fp, fn, tp = confusion_matrix(list(y_test[i+1]), list(y_pred[i])).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    tns.append(tn)
    fps.append(fp)
    fns.append(fn)
    tps.append(tp)
    print(f'Metrics for Defect {i+1}:')
    print(np.array([[tn, fp],[fn, tp]]))
    print(f'F1       : {2*(precision*recall)/(precision+recall):0.3f}')
    print(f'Recall   : {recall:0.3f}')
    print(f'Precision: {precision:0.3f}')
    print('')
    
precision = sum(tps)/(sum(tps)+sum(fps))
recall = sum(tps)/(sum(tps)+sum(fns))
print('Overall Metrics:')
print(np.array([[sum(tns), sum(fps)],[sum(fns), sum(tps)]]))
print(f'F1       : {2*(precision*recall)/(precision+recall):0.3f}')
print(f'Recall   : {recall:0.3f}')
print(f'Precision: {precision:0.3f}')
# Out:
# Metrics for Defect 1:
# [[1119  351]
#  [ 508  146]]
# F1       : 0.254
# Recall   : 0.223
# Precision: 0.294
#
# Metrics for Defect 2:
# [[1538  170]
#  [ 377   39]]
# F1       : 0.125
# Recall   : 0.094
# Precision: 0.187
#
# Metrics for Defect 3:
# [[650 524]
#  [526 424]]
# F1       : 0.447
# Recall   : 0.446
# Precision: 0.447
#
# Metrics for Defect 4:
# [[1125  404]
#  [ 426  169]]
# F1       : 0.289
# Recall   : 0.284
# Precision: 0.295
#
# Overall Metrics:
# [[4432 1449]
#  [1837  778]]
# F1       : 0.321
# Recall   : 0.298
# Precision: 0.349
