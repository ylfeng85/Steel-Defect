# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import keras
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import cv2
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
import tensorflow as tf
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout,BatchNormalization,SeparableConv2D
from keras.preprocessing.image import ImageDataGenerator
from collections import Counter, OrderedDict
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
from keras.layers import Embedding
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, LeakyReLU
from keras.layers import Flatten, Conv1D, SpatialDropout1D, MaxPooling1D,AveragePooling1D, merge, concatenate, Input, Dropout

from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import schedules

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# tf.config.set_visible_devices([], 'GPU')

# %%
files = []
directory = ''
for dirname, _, filenames in os.walk('/Users/tf/severstal-steel-defect-detection/train_images'):
    files = filenames
    directory = dirname

# %%
len(files)
# Out:
# 12568

# %%
file_df = pd.DataFrame(files, columns = ['ImageId'])

# %%
data = pd.read_csv("/Users/tf/severstal-steel-defect-detection/train.csv")

# %%
data.shape
# Out:
# (7095, 3)

# %%
data.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
data['ones'] = 1

# %%
pivot = data[['ImageId','ClassId','ones']].pivot(index='ImageId', columns='ClassId',values='ones').reset_index()

# %%
file_df = file_df.merge(pivot, how='left', on='ImageId').fillna(0)

# %%
file_df.shape
# Out:
# (12568, 5)

# %%
file_df.head()
# Out:
#          ImageId    1    2    3    4
# 0  58ee62fd7.jpg  0.0  0.0  1.0  0.0
# 1  eeffa4c49.jpg  1.0  0.0  1.0  0.0
# 2  0dced41aa.jpg  0.0  0.0  0.0  0.0
# 3  bd2366c49.jpg  0.0  0.0  0.0  0.0
# 4  e2bdd4236.jpg  0.0  0.0  1.0  0.0

# %%
# train/valid and test split

df_test = file_df.sample(frac=0.15, random_state=0)
print(df_test.shape)
# Out:
# (1885, 5)

# %%
exclude = file_df.index.isin(df_test.index)
df_train = file_df.loc[~exclude]
print(df_train.shape)
# Out:
# (10683, 5)

# %%
# remove non-defect rows

df_train = df_train[(df_train[[1,2,3,4]] != 0).any(axis=1)]
print(df_train.shape)
# Out:
# (5648, 5)

# %%
#  oversample data

df_train['rpt'] = 1 + df_train[1]*4 + df_train[4]*4 + df_train[2]*10 + \
                      df_train[1]*df_train[3]*4 + df_train[2]*df_train[3]*8 + df_train[1]*df_train[2]*4 + \
                      df_train[1]*df_train[2]*df_train[3]*12 + df_train[2]*df_train[4]*12

# %%
df_train = df_train.reindex(df_train.index.repeat(df_train.rpt)).reset_index(drop=True).drop(['rpt'],axis=1)
df_train.shape
# Out:
# (14166, 5)

# %%
# plot resampled distribution

y_counts_old = file_df.loc[~exclude][[1,2,3,4]].to_numpy()
counts = Counter(str(l) for l in y_counts_old)
counts = OrderedDict(counts.most_common())
counts = pd.DataFrame.from_dict(dict(counts), orient='index')

plt.figure(figsize=(15, 5))
plt.title('Original Distribution', fontsize=15)
plt.ylim(0,5200)
plt.bar(counts.index, counts[0])
plt.show()

y_counts_new = df_train[[1,2,3,4]].to_numpy()
counts2 = Counter(str(l) for l in y_counts_new)
counts2['[0. 0. 0. 0.]'] = 0
counts2 = pd.DataFrame.from_dict(dict(counts2), orient='index')
counts2 = counts2.loc[counts.index]

plt.figure(figsize=(15, 5))
plt.title('After Resampling', fontsize=15)
plt.ylim(0,5200)
plt.bar(counts2.index, counts2[0])
plt.show()

# %%
datagen=ImageDataGenerator(rescale=1./255., shear_range=20.0,
                           rotation_range=10, width_shift_range=0.2, height_shift_range=0.2,
                           horizontal_flip=True, vertical_flip=True, validation_split=0.15)

test_datagen=ImageDataGenerator(rescale=1./255.)

train_generator=datagen.flow_from_dataframe(dataframe=df_train,
                directory='/Users/tf/severstal-steel-defect-detection/train_images', subset="training",
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))

valid_generator=datagen.flow_from_dataframe(dataframe=df_train,
                directory='/Users/tf/severstal-steel-defect-detection/train_images', subset="validation",
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))

test_generator=test_datagen.flow_from_dataframe(dataframe=df_test,
                directory='/Users/tf/severstal-steel-defect-detection/train_images',
                x_col='ImageId', y_col=[1,2,3,4],
                batch_size=64,
                seed=0, shuffle=True,
                class_mode='raw', color_mode="grayscale",
                target_size=(71,71))
# Out:
# Found 12042 validated image filenames.
# Found 2124 validated image filenames.
# Found 1885 validated image filenames.

# %%
def model(output_dim=4, num_filters=8, filter_sizes=[(1,3),(3,3),(3,1)], dropout=0.2):

    model_input = Input(shape=(71,71,1))

    pooled_outputs = []
    for i in range(len(filter_sizes)):
        conv = SeparableConv2D(num_filters, kernel_size=filter_sizes[i], padding='same', activation=LeakyReLU(alpha=0.05))(model_input)
        conv = MaxPooling2D(pool_size=(2,2))(conv)
        pooled_outputs.append(conv)
    merge = concatenate(pooled_outputs)
    
    x = SeparableConv2D(16,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(merge)
    x = SeparableConv2D(16,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    
    x = SeparableConv2D(32,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = SeparableConv2D(32,(3,3),activation=LeakyReLU(alpha=0.05),padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = SeparableConv2D(24,(1,1),activation=LeakyReLU(alpha=0.05))(x)
    x = BatchNormalization()(x)
    
    flat = Flatten()(x)
    
    dense = Dropout(dropout)(flat)
    dense = Dense(50,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    dense = Dense(24,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    dense = Dense(24,activation=LeakyReLU(alpha=0.05))(dense)
    dense = Dropout(dropout)(dense)
    predictions = Dense(4,activation="sigmoid")(dense)
    
    model = Model(inputs=model_input,outputs=predictions)

    lr_schedule = schedules.ExponentialDecay(
        initial_learning_rate=0.0001,
        decay_steps=564,
        decay_rate=0.6)
    opt = optimizers.Adam(learning_rate=lr_schedule)
    
    model.compile(loss = 'binary_crossentropy', optimizer=opt, metrics=["accuracy",'binary_accuracy'])
    print(model.summary())
    
    return model

model = model()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 71, 71, 1)]  0           []
#
#  separable_conv2d_79 (Separable  (None, 71, 71, 8)   19          ['input_18[0][0]']
#  Conv2D)
#
#  separable_conv2d_80 (Separable  (None, 71, 71, 8)   25          ['input_18[0][0]']
#  Conv2D)
#
#  separable_conv2d_81 (Separable  (None, 71, 71, 8)   19          ['input_18[0][0]']
#  Conv2D)
#
#  max_pooling2d_73 (MaxPooling2D  (None, 35, 35, 8)   0           ['separable_conv2d_79[0][0]']
#  )
#
#  max_pooling2d_74 (MaxPooling2D  (None, 35, 35, 8)   0           ['separable_conv2d_80[0][0]']
#  )
#
#  max_pooling2d_75 (MaxPooling2D  (None, 35, 35, 8)   0           ['separable_conv2d_81[0][0]']
#  )
#
#  concatenate_12 (Concatenate)   (None, 35, 35, 24)   0           ['max_pooling2d_73[0][0]',
#                                                                   'max_pooling2d_74[0][0]',
#                                                                   'max_pooling2d_75[0][0]']
#
#  separable_conv2d_82 (Separable  (None, 35, 35, 16)  616         ['concatenate_12[0][0]']
#  Conv2D)
#
#  separable_conv2d_83 (Separable  (None, 35, 35, 16)  416         ['separable_conv2d_82[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 35, 35, 16)  64          ['separable_conv2d_83[0][0]']
#  ormalization)
#
#  max_pooling2d_76 (MaxPooling2D  (None, 17, 17, 16)  0           ['batch_normalization_47[0][0]']
#  )
#
#  separable_conv2d_84 (Separable  (None, 17, 17, 32)  688         ['max_pooling2d_76[0][0]']
#  Conv2D)
#
#  separable_conv2d_85 (Separable  (None, 17, 17, 32)  1344        ['separable_conv2d_84[0][0]']
#  Conv2D)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 32)  128         ['separable_conv2d_85[0][0]']
#  ormalization)
#
#  max_pooling2d_77 (MaxPooling2D  (None, 8, 8, 32)    0           ['batch_normalization_48[0][0]']
#  )
#
#  separable_conv2d_86 (Separable  (None, 8, 8, 24)    824         ['max_pooling2d_77[0][0]']
#  Conv2D)
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 24)    96          ['separable_conv2d_86[0][0]']
#  ormalization)
#
#  flatten_15 (Flatten)           (None, 1536)         0           ['batch_normalization_49[0][0]']
#
#  dropout_49 (Dropout)           (None, 1536)         0           ['flatten_15[0][0]']
#
#  dense_49 (Dense)               (None, 50)           76850       ['dropout_49[0][0]']
#
#  dropout_50 (Dropout)           (None, 50)           0           ['dense_49[0][0]']
#
#  dense_50 (Dense)               (None, 24)           1224        ['dropout_50[0][0]']
#
#  dropout_51 (Dropout)           (None, 24)           0           ['dense_50[0][0]']
#
#  dense_51 (Dense)               (None, 24)           600         ['dropout_51[0][0]']
#
#  dropout_52 (Dropout)           (None, 24)           0           ['dense_51[0][0]']
#
#  dense_52 (Dense)               (None, 4)            100         ['dropout_52[0][0]']
#
# ==================================================================================================
# Total params: 83,013
# Trainable params: 82,869
# Non-trainable params: 144
# __________________________________________________________________________________________________
# None

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
print(STEP_SIZE_TRAIN)
print(STEP_SIZE_VALID)
print(STEP_SIZE_TEST)
# Out:
# 188
# 33
# 29

# %%
callback_list = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='./[model3]-{epoch:02d}-{val_loss:.3f}.h5'),
]

history = model.fit(x=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25,
                    callbacks=callback_list,
                    verbose=1)
# Out:
# Epoch 1/25
# 188/188 [==============================] - 95s 445ms/step - loss: 0.6382 - accuracy: 0.3329 - binary_accuracy: 0.6141 - val_loss: 0.6831 - val_accuracy: 0.3087 - val_binary_accuracy: 0.6920
# Epoch 2/25
# 188/188 [==============================] - 101s 535ms/step - loss: 0.5812 - accuracy: 0.3707 - binary_accuracy: 0.6721 - val_loss: 0.6695 - val_accuracy: 0.3063 - val_binary_accuracy: 0.6495
# Epoch 3/25
# 188/188 [==============================] - 115s 606ms/step - loss: 0.5525 - accuracy: 0.3952 - binary_accuracy: 0.6937 - val_loss: 0.6328 - val_accuracy: 0.3134 - val_binary_accuracy: 0.6417
# Epoch 4/25
# 188/188 [==============================] - 115s 609ms/step - loss: 0.5322 - accuracy: 0.4304 - binary_accuracy: 0.7093 - val_loss: 0.5392 - val_accuracy: 0.4782 - val_binary_accuracy: 0.7196
# Epoch 5/25
# 188/188 [==============================] - 114s 606ms/step - loss: 0.5224 - accuracy: 0.4385 - binary_accuracy: 0.7141 - val_loss: 0.4966 - val_accuracy: 0.4962 - val_binary_accuracy: 0.7328
# Epoch 6/25
# 188/188 [==============================] - 98s 516ms/step - loss: 0.5139 - accuracy: 0.4490 - binary_accuracy: 0.7185 - val_loss: 0.4861 - val_accuracy: 0.4972 - val_binary_accuracy: 0.7434
# Epoch 7/25
# 188/188 [==============================] - 94s 499ms/step - loss: 0.5093 - accuracy: 0.4580 - binary_accuracy: 0.7231 - val_loss: 0.4854 - val_accuracy: 0.5033 - val_binary_accuracy: 0.7437
# Epoch 8/25
# 188/188 [==============================] - 110s 585ms/step - loss: 0.5025 - accuracy: 0.4707 - binary_accuracy: 0.7298 - val_loss: 0.4814 - val_accuracy: 0.4991 - val_binary_accuracy: 0.7473
# Epoch 9/25
# 188/188 [==============================] - 120s 635ms/step - loss: 0.5025 - accuracy: 0.4688 - binary_accuracy: 0.7284 - val_loss: 0.4759 - val_accuracy: 0.5142 - val_binary_accuracy: 0.7527
# Epoch 10/25
# 188/188 [==============================] - 123s 645ms/step - loss: 0.4988 - accuracy: 0.4722 - binary_accuracy: 0.7323 - val_loss: 0.4727 - val_accuracy: 0.5024 - val_binary_accuracy: 0.7531
# Epoch 11/25
# 188/188 [==============================] - 115s 612ms/step - loss: 0.4945 - accuracy: 0.4723 - binary_accuracy: 0.7335 - val_loss: 0.4720 - val_accuracy: 0.5175 - val_binary_accuracy: 0.7592
# Epoch 12/25
# 188/188 [==============================] - 132s 699ms/step - loss: 0.4939 - accuracy: 0.4793 - binary_accuracy: 0.7338 - val_loss: 0.4726 - val_accuracy: 0.5241 - val_binary_accuracy: 0.7493
# Epoch 13/25
# 188/188 [==============================] - 135s 717ms/step - loss: 0.4944 - accuracy: 0.4773 - binary_accuracy: 0.7337 - val_loss: 0.4734 - val_accuracy: 0.5090 - val_binary_accuracy: 0.7522

# %% [markdown]
# ### Results

# %%
history_df = pd.DataFrame(history.history)
history_df.index += 1

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['loss','val_loss']], lw=2)
plt.title('Loss (Binary Cross Entropy)', fontsize=20)
plt.legend(['Training Loss','Validation Loss'], fontsize=12, loc=1)
plt.xlim(0.5,21.5)
plt.ylim(0.45,0.7)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.45, 0.75, step=0.05))
plt.grid()
plt.show()

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['accuracy','val_accuracy']], lw=2)
plt.title('Accuracy', fontsize=20)
plt.legend(['Training Accuracy','Validation Accuracy'], fontsize=12, loc=4)
plt.xlim(0.5,21.5)
plt.ylim(0.3,0.56)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.3, 0.6, step=0.05))
plt.grid()
plt.show()

# %%
plt.subplots(figsize=(20,8))
plt.plot(history_df.loc[:, ['binary_accuracy','val_binary_accuracy']], lw=2)
plt.title('Binary Accuracy', fontsize=20)
plt.legend(['Training Binary Accuracy','Validation Binary Accuracy'], fontsize=12, loc=4)
plt.xlim(0.5,21.5)
plt.ylim(0.575,0.775)
plt.xticks(np.arange(1, 22, step=1))
plt.yticks(np.arange(0.575, 0.775, step=0.025))
plt.grid()
plt.show()

# %%
from keras.models import load_model
saved_model = load_model('/Users/tf/Desktop/[model3]-11-0.472.h5')

# %%
y_eval = saved_model.evaluate(valid_generator)
valid_generator.reset()

y_pred = saved_model.predict(valid_generator, verbose=1)
y_pred[y_pred > 0.5] = 1
y_pred[y_pred <= 0.5] = 0
y_pred = pd.DataFrame(y_pred)

y_test = df_train.loc[valid_generator.index_array]
# Out:
# 34/34 [==============================] - 9s 240ms/step - loss: 0.4741 - accuracy: 0.5080 - binary_accuracy: 0.7553
# 34/34 [==============================] - 9s 243ms/step

# %%
print(y_eval)
# Out:
# [0.47411930561065674, 0.5080037713050842, 0.7552965879440308]

# %%
tns, fps, fns, tps = [],[],[],[]

for i in range(4):
    tn, fp, fn, tp = confusion_matrix(list(y_test[i+1]), list(y_pred[i])).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    tns.append(tn)
    fps.append(fp)
    fns.append(fn)
    tps.append(tp)
    print(f'Metrics for Defect {i+1}:')
    print(np.array([[tn, fp],[fn, tp]]))
    print(f'F1       : {2*(precision*recall)/(precision+recall):0.3f}')
    print(f'Recall   : {recall:0.3f}')
    print(f'Precision: {precision:0.3f}')
    print('')
    
precision = sum(tps)/(sum(tps)+sum(fps))
recall = sum(tps)/(sum(tps)+sum(fns))
print('Overall Metrics:')
print(np.array([[sum(tns), sum(fps)],[sum(fns), sum(tps)]]))
print(f'F1       : {2*(precision*recall)/(precision+recall):0.3f}')
print(f'Recall   : {recall:0.3f}')
print(f'Precision: {precision:0.3f}')
# Out:
# Metrics for Defect 1:
# [[1245  225]
#  [ 544  110]]
# F1       : 0.222
# Recall   : 0.168
# Precision: 0.328
#
# Metrics for Defect 2:
# [[1328  380]
#  [ 326   90]]
# F1       : 0.203
# Recall   : 0.216
# Precision: 0.191
#
# Metrics for Defect 3:
# [[935 239]
#  [741 209]]
# F1       : 0.299
# Recall   : 0.220
# Precision: 0.467
#
# Metrics for Defect 4:
# [[1201  328]
#  [ 462  133]]
# F1       : 0.252
# Recall   : 0.224
# Precision: 0.289
#
# Overall Metrics:
# [[4709 1172]
#  [2073  542]]
# F1       : 0.250
# Recall   : 0.207
# Precision: 0.316
